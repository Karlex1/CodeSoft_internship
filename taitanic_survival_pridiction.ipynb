# %% [markdown]
# Importing Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

dataset=pd.read_csv('../datasets/tested.csv')

# %% [markdown]
# Observing Dataset

# %%
dataset
# Out:
#      PassengerId  Survived  Pclass
# 0            892         0       3  \
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch
# 0                                Kelly, Mr. James    male  34.5      0      0  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
dataset.shape
# Out:
# (418, 12)

# %%
dataset.head(20)
# Out:
#     PassengerId  Survived  Pclass
# 0           892         0       3  \
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
# 15          907         1       2
# 16          908         0       2
# 17          909         0       3
# 18          910         1       3
# 19          911         1       3
#
#                                                  Name     Sex   Age  SibSp
# 0                                    Kelly, Mr. James    male  34.5      0  \
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# ...

# %% [markdown]
# Observing Age column

# %%
dataset.Age
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %% [markdown]
# from above table we can see that the dataset.Age have null value.

# %%
#survival
survival_count=dataset.Survived.value_counts()
survival_rate=100*survival_count/dataset.shape[0]
survival_rate
# Out:
# Survived
# 0    63.636364
# 1    36.363636
# Name: count, dtype: float64

# %%
survival_data=pd.concat((survival_count,survival_rate),axis=1).reset_index()
survival_data.columns=['Survived','Count','Percentage']
survival_data
# Out:
#    Survived  Count  Percentage
# 0         0    266   63.636364
# 1         1    152   36.363636

# %%
plt.figure(figsize=(3,3))
sns.barplot(survival_data,x=('Not-Survived','Survived'),y='Percentage',width=0.50)
plt.xlabel('Survival status')
plt.ylabel('Percentage')
plt.title('Figure to show Survival_data')
# Out:
# Text(0.5, 1.0, 'Figure to show Survival_data')
